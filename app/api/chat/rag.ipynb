# %% [markdown]
# # Imports

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (24.2)

# %%
# !pip install langchain langchain-community openai tiktoken pinecone-client langchain_pinecone unstructured 
# !pip install pdfminer==20191125 pdfminer.six==20221105 pillow_heif unstructured_inference youtube-transcript-api pytube 
# !pip install sentence-transformers python-dotenv retry datasets
# !pip install -qU langchain-text-splitters
# !pip install -U langchain-huggingface langchain-pinecone
# !pip install -U sentence-transformers
# !pip install --upgrade --quiet  praw
# !pip install -qU langchain-pinecone pinecone-notebooks
# Out:
# Requirement already satisfied: langchain in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (0.2.12)
# Requirement already satisfied: langchain-community in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (0.2.11)
# Requirement already satisfied: openai in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (1.40.3)
# Requirement already satisfied: tiktoken in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (0.7.0)
# Requirement already satisfied: pinecone-client in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (5.0.1)
# Requirement already satisfied: langchain_pinecone in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (0.1.3)
# Requirement already satisfied: unstructured in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (0.15.1)
# Requirement already satisfied: PyYAML>=5.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from langchain) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from langchain) (3.10.2)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.27 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from langchain) (0.2.29)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from langchain) (0.2.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from langchain) (0.1.98)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from langchain) (1.26.3)
# Requirement already satisfied: pydantic<3,>=1 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from langchain) (2.8.2)
# Requirement already satisfied: requests<3,>=2 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from langchain) (8.2.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from openai) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from openai) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from openai) (0.5.0)
# Requirement already satisfied: sniffio in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from openai) (4.12.2)
# Requirement already satisfied: regex>=2022.1.18 in /Users/katrina/Library/Python/3.12/lib/python/site-packages (from tiktoken) (2023.12.25)
# Requirement already satisfied: certifi>=2019.11.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pinecone-client) (2024.7.4)
# Requirement already satisfied: pinecone-plugin-inference<2.0.0,>=1.0.3 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from pinecone-client) (1.0.3)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from pinecone-client) (0.0.7)
# Requirement already satisfied: urllib3>=1.26.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pinecone-client) (2.2.0)
# Requirement already satisfied: chardet in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from unstructured) (5.2.0)
# Requirement already satisfied: filetype in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: python-magic in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: lxml in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from unstructured) (5.2.1)
# Requirement already satisfied: nltk in /Users/katrina/Library/Python/3.12/lib/python/site-packages (from unstructured) (3.8.1)
# Requirement already satisfied: tabulate in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from unstructured) (0.9.0)
# Requirement already satisfied: beautifulsoup4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from unstructured) (4.12.3)
# Requirement already satisfied: emoji in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from unstructured) (2.12.1)
# Requirement already satisfied: python-iso639 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from unstructured) (2024.4.27)
# Requirement already satisfied: langdetect in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: rapidfuzz in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from unstructured) (3.9.6)
# Requirement already satisfied: backoff in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: unstructured-client in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from unstructured) (0.25.4)
# Requirement already satisfied: wrapt in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from unstructured) (1.16.0)
# Requirement already satisfied: psutil in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from unstructured) (5.9.8)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.3.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: idna>=2.8 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.27->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.27->langchain) (24.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.7)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from pydantic<3,>=1->langchain) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: soupsieve>1.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from beautifulsoup4->unstructured) (2.5)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from langdetect->unstructured) (1.16.0)
# Requirement already satisfied: click in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nltk->unstructured) (8.1.7)
# Requirement already satisfied: joblib in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nltk->unstructured) (1.4.0)
# Requirement already satisfied: deepdiff>=6.0 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from unstructured-client->unstructured) (7.0.1)
# Requirement already satisfied: jsonpath-python>=1.0.6 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from unstructured-client->unstructured) (1.0.6)
# Requirement already satisfied: mypy-extensions>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: nest-asyncio>=1.6.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from unstructured-client->unstructured) (1.6.0)
# Requirement already satisfied: pypdf>=4.0 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from unstructured-client->unstructured) (4.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from unstructured-client->unstructured) (2.9.0.post0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: ordered-set<4.2.0,>=4.1.0 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from deepdiff>=6.0->unstructured-client->unstructured) (4.1.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.27->langchain) (2.4)
# Requirement already satisfied: pdfminer==20191125 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (20191125)
# Requirement already satisfied: pdfminer.six==20221105 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (20221105)
# Requirement already satisfied: pillow_heif in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (0.18.0)
# Requirement already satisfied: unstructured_inference in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (0.7.36)
# Requirement already satisfied: youtube-transcript-api in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (0.6.2)
# Requirement already satisfied: pytube in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (15.0.0)
# Requirement already satisfied: pycryptodome in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from pdfminer==20191125) (3.20.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pdfminer.six==20221105) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from pdfminer.six==20221105) (43.0.0)
# Requirement already satisfied: pillow>=10.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pillow_heif) (10.2.0)
# Requirement already satisfied: layoutparser in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from unstructured_inference) (0.3.4)
# Requirement already satisfied: python-multipart in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from unstructured_inference) (0.0.9)
# Requirement already satisfied: huggingface-hub in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from unstructured_inference) (0.24.5)
# Requirement already satisfied: opencv-python!=4.7.0.68 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from unstructured_inference) (4.10.0.84)
# Requirement already satisfied: onnx in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from unstructured_inference) (1.16.2)
# Requirement already satisfied: onnxruntime>=1.17.0 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from unstructured_inference) (1.18.1)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from unstructured_inference) (3.8.4)
# Requirement already satisfied: torch in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from unstructured_inference) (2.2.0)
# Requirement already satisfied: timm in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from unstructured_inference) (1.0.8)
# Requirement already satisfied: transformers>=4.25.1 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from unstructured_inference) (4.44.0)
# Requirement already satisfied: rapidfuzz in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from unstructured_inference) (3.9.6)
# Requirement already satisfied: requests in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from youtube-transcript-api) (2.32.3)
# Requirement already satisfied: cffi>=1.12 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from cryptography>=36.0.0->pdfminer.six==20221105) (1.16.0)
# Requirement already satisfied: coloredlogs in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from onnxruntime>=1.17.0->unstructured_inference) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from onnxruntime>=1.17.0->unstructured_inference) (24.3.25)
# Requirement already satisfied: numpy<2.0,>=1.21.6 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from onnxruntime>=1.17.0->unstructured_inference) (1.26.3)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from onnxruntime>=1.17.0->unstructured_inference) (24.0)
# Requirement already satisfied: protobuf in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from onnxruntime>=1.17.0->unstructured_inference) (4.25.3)
# Requirement already satisfied: sympy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from onnxruntime>=1.17.0->unstructured_inference) (1.12)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers>=4.25.1->unstructured_inference) (3.13.1)
# Requirement already satisfied: pyyaml>=5.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers>=4.25.1->unstructured_inference) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/katrina/Library/Python/3.12/lib/python/site-packages (from transformers>=4.25.1->unstructured_inference) (2023.12.25)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from transformers>=4.25.1->unstructured_inference) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from transformers>=4.25.1->unstructured_inference) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from transformers>=4.25.1->unstructured_inference) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from huggingface-hub->unstructured_inference) (2023.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from huggingface-hub->unstructured_inference) (4.12.2)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from layoutparser->unstructured_inference) (1.13.0)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from layoutparser->unstructured_inference) (2.2.1)
# Requirement already satisfied: iopath in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from layoutparser->unstructured_inference) (0.1.10)
# Requirement already satisfied: pdfplumber in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from layoutparser->unstructured_inference) (0.10.4)
# Requirement already satisfied: pdf2image in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from layoutparser->unstructured_inference) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->unstructured_inference) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->unstructured_inference) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->unstructured_inference) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->unstructured_inference) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->unstructured_inference) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->unstructured_inference) (2.9.0.post0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->youtube-transcript-api) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->youtube-transcript-api) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->youtube-transcript-api) (2024.7.4)
# Requirement already satisfied: torchvision in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from timm->unstructured_inference) (0.17.0)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch->unstructured_inference) (3.2.1)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch->unstructured_inference) (3.1.3)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20221105) (2.22)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->unstructured_inference) (1.16.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from coloredlogs->onnxruntime>=1.17.0->unstructured_inference) (10.0)
# Requirement already satisfied: portalocker in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from iopath->layoutparser->unstructured_inference) (2.10.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jinja2->torch->unstructured_inference) (2.1.5)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas->layoutparser->unstructured_inference) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas->layoutparser->unstructured_inference) (2024.1)
# Requirement already satisfied: pypdfium2>=4.18.0 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from pdfplumber->layoutparser->unstructured_inference) (4.30.0)
# Requirement already satisfied: mpmath>=0.19 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sympy->onnxruntime>=1.17.0->unstructured_inference) (1.3.0)
# Requirement already satisfied: sentence-transformers in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (3.0.1)
# Requirement already satisfied: python-dotenv in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (1.0.1)
# Requirement already satisfied: retry in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (0.9.2)
# Requirement already satisfied: datasets in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (2.20.0)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from sentence-transformers) (4.44.0)
# Requirement already satisfied: tqdm in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sentence-transformers) (2.2.0)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sentence-transformers) (1.26.3)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sentence-transformers) (1.4.1.post1)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sentence-transformers) (1.13.0)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from sentence-transformers) (0.24.5)
# Requirement already satisfied: Pillow in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sentence-transformers) (10.2.0)
# Requirement already satisfied: decorator>=3.4.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from retry) (5.1.1)
# Requirement already satisfied: py<2.0.0,>=1.4.26 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from retry) (1.11.0)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from datasets) (3.13.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from datasets) (15.0.2)
# Requirement already satisfied: pyarrow-hotfix in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from datasets) (2.2.1)
# Requirement already satisfied: requests>=2.32.2 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: xxhash in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.5.0,>=2023.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from fsspec[http]<=2024.5.0,>=2023.1.0->datasets) (2023.12.2)
# Requirement already satisfied: aiohttp in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from datasets) (3.10.2)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from aiohttp->datasets) (2.3.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (2024.7.4)
# Requirement already satisfied: sympy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/katrina/Library/Python/3.12/lib/python/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2023.12.25)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: joblib>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (3.4.0)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: langchain-huggingface in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (0.0.3)
# Requirement already satisfied: langchain-pinecone in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (0.1.3)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from langchain-huggingface) (0.24.5)
# Requirement already satisfied: langchain-core<0.3,>=0.1.52 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from langchain-huggingface) (0.2.29)
# Requirement already satisfied: sentence-transformers>=2.6.0 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from langchain-huggingface) (3.0.1)
# Requirement already satisfied: tokenizers>=0.19.1 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from langchain-huggingface) (0.19.1)
# Requirement already satisfied: transformers>=4.39.0 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from langchain-huggingface) (4.44.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.5 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from langchain-pinecone) (3.10.2)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from langchain-pinecone) (1.26.3)
# Requirement already satisfied: pinecone-client<6.0.0,>=5.0.0 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from langchain-pinecone) (5.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.5->langchain-pinecone) (2.3.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.5->langchain-pinecone) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.5->langchain-pinecone) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.5->langchain-pinecone) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.5->langchain-pinecone) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.5->langchain-pinecone) (1.9.4)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (2023.12.2)
# Requirement already satisfied: packaging>=20.9 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (6.0.1)
# Requirement already satisfied: requests in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (4.12.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from langchain-core<0.3,>=0.1.52->langchain-huggingface) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from langchain-core<0.3,>=0.1.52->langchain-huggingface) (0.1.98)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from langchain-core<0.3,>=0.1.52->langchain-huggingface) (2.8.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from langchain-core<0.3,>=0.1.52->langchain-huggingface) (8.2.3)
# Requirement already satisfied: certifi>=2019.11.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pinecone-client<6.0.0,>=5.0.0->langchain-pinecone) (2024.7.4)
# Requirement already satisfied: pinecone-plugin-inference<2.0.0,>=1.0.3 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from pinecone-client<6.0.0,>=5.0.0->langchain-pinecone) (1.0.3)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from pinecone-client<6.0.0,>=5.0.0->langchain-pinecone) (0.0.7)
# Requirement already satisfied: urllib3>=1.26.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pinecone-client<6.0.0,>=5.0.0->langchain-pinecone) (2.2.0)
# Requirement already satisfied: torch>=1.11.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (2.2.0)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (1.4.1.post1)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (1.13.0)
# Requirement already satisfied: Pillow in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (10.2.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/katrina/Library/Python/3.12/lib/python/site-packages (from transformers>=4.39.0->langchain-huggingface) (2023.12.25)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from transformers>=4.39.0->langchain-huggingface) (0.4.4)
# Requirement already satisfied: jsonpointer>=1.9 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.1.52->langchain-huggingface) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.1.52->langchain-huggingface) (3.10.7)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.3,>=0.1.52->langchain-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.3,>=0.1.52->langchain-huggingface) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface) (3.6)
# Requirement already satisfied: sympy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (1.12)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (3.2.1)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (3.1.3)
# Requirement already satisfied: joblib>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface) (3.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sympy->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (1.3.0)
# Requirement already satisfied: sentence-transformers in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (3.0.1)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from sentence-transformers) (4.44.0)
# Requirement already satisfied: tqdm in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sentence-transformers) (2.2.0)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sentence-transformers) (1.26.3)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sentence-transformers) (1.4.1.post1)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sentence-transformers) (1.13.0)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from sentence-transformers) (0.24.5)
# Requirement already satisfied: Pillow in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sentence-transformers) (10.2.0)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2023.12.2)
# Requirement already satisfied: packaging>=20.9 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.12.2)
# Requirement already satisfied: sympy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/katrina/Library/Python/3.12/lib/python/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2023.12.25)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /Users/katrina/Files/Projects/Headstarter/customer-support-ai/.venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: joblib>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (3.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.7.4)
# Requirement already satisfied: mpmath>=0.19 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)

# %%
import os
import ssl
import numpy as np
import pandas as pd
import requests
import torch

from dotenv import load_dotenv
from pinecone import Pinecone
from sentence_transformers import SentenceTransformer
from sentence_transformers.util import semantic_search


from langchain.text_splitter import CharacterTextSplitter
from langchain_pinecone import PineconeVectorStore

from langchain.document_loaders import YoutubeLoader
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate

# %% [markdown]
# # Env. Variables

# %%
load_dotenv()
pinecone_key = os.getenv("PINECONE_API_KEY")
openrouter_key = os.getenv("OPEN_ROUTER_API_KEY")
model_id = os.getenv("HF_MODEL_ID")
api_url = f"https://api-inference.huggingface.co/pipeline/feature-extraction/{os.getenv("HF_MODEL_ID")}"

api_url
headers = {"Authorization": f"Bearer {os.getenv('HF_TOKEN')}"}

# %%
template = """Use the following pieces of context to answer the question at the end. 
If you don't know the answer, just say that you don't know, don't try to make up an answer.

{context}

Question: {question}
Answer:"""

QA_CHAIN_PROMPT = PromptTemplate(
    input_variables=["context", "question"],
    template=template,
)

qa_chain = RetrievalQA.from_chain_type(
    chain_type="stuff",
    retriever=vectorstore.as_retriever(),
    chain_type_kwargs={"prompt": QA_CHAIN_PROMPT},
    return_source_documents=True
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 16
#       1 template = """Use the following pieces of context to answer the question at the end.
#       2 If you don't know the answer, just say that you don't know, don't try to make up an answer.
#       3
#    (...)
#       6 Question: {question}
#       7 Answer:"""
#       9 QA_CHAIN_PROMPT = PromptTemplate(
#      10     input_variables=["context", "question"],
#      11     template=template,
#      12 )
#      14 qa_chain = RetrievalQA.from_chain_type(
#      15     chain_type="stuff",
# ---> 16     retriever=vectorstore.as_retriever(),
#      17     chain_type_kwargs={"prompt": QA_CHAIN_PROMPT},
#      18     return_source_documents=True
#      19 )
#
# NameError: name 'vectorstore' is not defined

# %%
def perform_rag():
    result = qa_chain({"query": query})
    return result["result"]


query = perform_rag()
print(query)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 6
#       2     result = qa_chain({"query": query})
#       3     return result["result"]
# ----> 6 query = perform_rag()
#       7 print(query)
#
# Cell In[10], line 2, in perform_rag()
#       1 def perform_rag():
# ----> 2     result = qa_chain({"query": query})
#       3     return result["result"]
#
# NameError: name 'qa_chain' is not defined

# %%
text_splitter = CharacterTextSplitter(
    separator=" ",
    chunk_size=800,
    chunk_overlap=200,
    length_function=len,
)

# %%
urls = [
    "https://www.youtube.com/watch?v=8EYW2v4G9bw",
    "https://youtu.be/fOnUAAUXC1E?si=aQueTvxQ02BWq6se",
    "https://youtu.be/SD0PprfHFd0?si=jWGehEKC84k4uZiQ",
    "https://youtu.be/NUhDP30IRKk?si=i3PNGHL4rOVTCcWB",
    "https://youtu.be/Tt08KmFfIYQ?si=U2a7mdAThgrWlW5x",
    "https://youtu.be/31EWjB_9Jig?si=RMP2YfFyTxp0qTJA",
    "https://youtu.be/Ka0JgkZTHwY?si=cFV8Chv3Hscgl7DA",
    "https://youtu.be/pjqi_M3SPwY?si=UWcrvfx7FFPaZ9dk",
    "https://youtu.be/0SARbwvhupQ?si=SblTzsXZ5Ueja2qY",
    "https://www.youtube.com/live/InHF1nl4pu0?si=aFSGO4ovz4IlHzgv"
    
]

# %%
def load_videos(url):
    loader = YoutubeLoader.from_youtube_url(
    url, add_video_info=True
    )
    data = loader.load()
    return data


text = []
def get_texts(urls):
    for url in urls:
        data = load_videos(url)
        text.append(text_splitter.split_documents(data))
        return text
    
texts = get_texts(urls)

# %%
def get_embeddings(texts):
    response = requests.post(api_url, headers=headers, json={"inputs": texts, "options": {"wait_for_model": True}})
    return response.json()

embeddings = HuggingFaceEmbeddings(api_url=api_url, headers=headers)

# %%
output = query(texts[0].page_content)
video_embeddings = pd.DataFrame(output)
video_embeddings

# %%
video_embeds = torch.from_numpy(video_embeddings.to_numpy()).to(torch.float)

# Check if video_embeds needs to be reshaped
if video_embeds.shape[0] == 384 and video_embeds.shape[1] == 1:
    video_embeds = video_embeds.T  # Transpose to get (num_videos, 384)

# For testing purposes, unsqueeze if it is a 1D tensor to make it 2D
if video_embeds.dim() == 1:
    video_embeds = video_embeds.unsqueeze(0)

# %%
pc = Pinecone(api_key=os.getenv("PINECONE_API_KEY"))

index_name = os.getenv("PINECONE_INDEX_NAME")
index = pc.Index(os.getenv("PINECONE_INDEX_NAME"))
namespace = os.getenv("PINECONE_NAMESPACE")

vectorstore = PineconeVectorStore.from_texts(
    [f"Source: {t.metadata['source']}\n\nContent: {t.page_content}" for t in texts],
    embeddings,
    index_name=index_name,
    namespace=namespace
)

# %%
question = perform_rag()
output = query(question)

query_embeddings = torch.FloatTensor(output)

# %%
hits = semantic_search(query_embeddings, video_embeds, top_k=5)

# %%
matches = ([texts[hits[0][i]['corpus_id']] for i in range(len(hits[0]))])

# %%
def query_pinecone(query):
    query_embedding = get_embeddings([query])[0]
    results = index.query(
        vector=query_embedding,
        top_k=5,
        include_metadata=True,
        namespace=namespace
    )
    return results


results = query_pinecone("Your question here")
for result in results['matches']:
    print(f"Score: {result['score']}, Metadata: {result['metadata']}")
